# %%
# !git clone https://github.com/AlwaysDhruv/Lamly.git
# Out:
# Cloning into 'Lamly'...
# remote: Enumerating objects: 695, done.
# remote: Counting objects: 100% (318/318), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 695 (delta 245), reused 198 (delta 128), pack-reused 377 (from 1)
# Receiving objects: 100% (695/695), 12.02 MiB | 13.78 MiB/s, done.
# Resolving deltas: 100% (447/447), done.

# %%
cd Lamly/src
# Out:
# /content/Lamly/src

# %%
# !nvcc -std=c++20 main.cu -Iinclude -lcurand -o app && ./app
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./include/BPE.hpp(464): warning #780-D: reference is to variable "i" (declared at line 399) -- under old for-init scoping rules it would have been variable "i" (declared at line 407)
#                   cout << i + 1 << ". " << tk1 << " : " << fre[0].token1 << " & " << tk2 << " : " << fre[0].token2 << " => "<< tk << " : " << fre[0].merge << endl;
#                           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# ./include/BPE.hpp(503): warning #780-D: reference is to variable "i" (declared at line 399) -- under old for-init scoping rules it would have been variable "i" (declared at line 407)
#                     else cout << i + 1 << " Already Exist In " << path << "!!" << endl;
#                                  ^
#
# ...
