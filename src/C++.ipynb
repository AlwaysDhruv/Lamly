# %%
# !git clone https://github.com/AlwaysDhruv/GPT-CPP.git
# Out:
# Cloning into 'GPT-CPP'...
# remote: Enumerating objects: 541, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 541 (delta 126), reused 106 (delta 72), pack-reused 377 (from 1)
# Receiving objects: 100% (541/541), 11.91 MiB | 13.15 MiB/s, done.
# Resolving deltas: 100% (328/328), done.

# %%
cd GPT-CPP/src/
# Out:
# /content/GPT-CPP/src/GPT-CPP/src

# %%
# !nvcc -std=c++20 main.cu -Iinclude -lcurand -o app && ./app
# Out:
# Streaming output truncated to the last 5000 lines.
#     [ -1.93426e-38 -1.93426e-38 5.80287e-38 -1.93426e-38 ]
#     [ 0 0 0 0 ]
#     [ -2.48875e-10 7.46626e-10 -2.48875e-10 -2.48875e-10 ]
#     [ 2.76376e-06 -9.2059e-07 -9.21586e-07 -9.21586e-07 ]
#     [ 2.76376e-06 -9.2059e-07 -9.21586e-07 -9.21586e-07 ]
#     [ -2.48875e-10 7.46626e-10 -2.48875e-10 -2.48875e-10 ]
#     [ 2.76376e-06 -9.2059e-07 -9.21586e-07 -9.21586e-07 ]
#     [ 2.76376e-06 -9.2059e-07 -9.21586e-07 -9.21586e-07 ]
#   ]
#   [
#     [ 2.76401e-06 -9.21337e-07 -9.21337e-07 -9.21337e-07 ]
#     [ -2.48875e-10 7.46626e-10 -2.48875e-10 -2.48875e-10 ]
#     [ 0 0 0 0 ]
#     [ -2.48875e-10 7.46626e-10 -2.48875e-10 -2.48875e-10 ]
#     [ -2.48875e-10 7.46626e-10 -2.48875e-10 -2.48875e-10 ]
#     [ 2.76401e-06 -9.21337e-07 -9.21337e-07 -9.21337e-07 ]
#     [ 2.76376e-06 -9.2059e-07 -9.21586e-07 -9.21586e-07 ]
#     [ 2.76401e-06 -9.21337e-07 -9.21337e-07 -9.21337e-07 ]
#   ]
#   [
#     [ 0 0 0 0 ]
# ...
